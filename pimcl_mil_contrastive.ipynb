# %% [markdown]
# <a href="https://colab.research.google.com/github/tousifo/ml_notebooks/blob/main/pimcl_mil_contrastive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Preprocess

# %%
# !pip install SimpleITK torchio nilearn
# Out:
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.11/dist-packages (2.5.0)
# Requirement already satisfied: torchio in /usr/local/lib/python3.11/dist-packages (0.20.8)
# Requirement already satisfied: nilearn in /usr/local/lib/python3.11/dist-packages (0.11.1)
# Requirement already satisfied: deprecated>=1.2 in /usr/local/lib/python3.11/dist-packages (from torchio) (1.2.18)
# Requirement already satisfied: einops>=0.3 in /usr/local/lib/python3.11/dist-packages (from torchio) (0.8.1)
# Requirement already satisfied: humanize>=0.1 in /usr/local/lib/python3.11/dist-packages (from torchio) (4.12.3)
# Requirement already satisfied: nibabel>=3 in /usr/local/lib/python3.11/dist-packages (from torchio) (5.3.2)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from torchio) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from torchio) (24.2)
# Requirement already satisfied: rich>=10 in /usr/local/lib/python3.11/dist-packages (from torchio) (13.9.4)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.11/dist-packages (from torchio) (1.15.3)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.11/dist-packages (from torchio) (2.6.0+cu124)
# Requirement already satisfied: tqdm>=4.40 in /usr/local/lib/python3.11/dist-packages (from torchio) (4.67.1)
# Requirement already satisfied: typer>=0.1 in /usr/local/lib/python3.11/dist-packages (from torchio) (0.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (1.5.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from nilearn) (5.4.0)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (2.2.2)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (1.6.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2->torchio) (1.17.2)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel>=3->torchio) (6.5.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel>=3->torchio) (4.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->nilearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->nilearn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->nilearn) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10->torchio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10->torchio) (2.19.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.0->nilearn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->torchio) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.9->torchio) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.1->torchio) (8.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.1->torchio) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10->torchio) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nilearn) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.9->torchio) (3.0.2)

# %%
# %%writefile preprocess.py
import os
import zipfile
import numpy as np
import subprocess
import sys
import argparse
from glob import glob
import SimpleITK as sitk
import nibabel as nib
from nilearn import datasets

# Fallback dependency installation
for pkg in ['simpleitk', 'torchio', 'nilearn']:
    try:
        __import__(pkg)
    except ImportError:
        print(f"Installing {pkg}...")
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', pkg])

# Hyperparameter Configuration
parser = argparse.ArgumentParser(description='PMICL Training')
parser.add_argument('--emb_dim', type=int, default=256)
parser.add_argument('--protos_per_class', type=int, default=3)
parser.add_argument('--lambda_proto', type=float, default=0.5)
parser.add_argument('--patch_size', type=int, default=32)
parser.add_argument('--stride', type=int, default=32)
parser.add_argument('--N', type=int, default=64)
parser.add_argument('--max_files', type=int, default=None)
parser.add_argument('--epochs', type=int, default=20)
parser.add_argument('--batch_size', type=int, default=2)
args, _ = parser.parse_known_args()

# Paths
ZIP_PATH = '/content/oaisis.zip'
RAW_DIR = '/content/oasis_raw'
PREPROC_DIR = '/content/oasis_preproc'
MNI_TEMPLATE = '/content/icbm152_2009/mni_icbm152_nlin_sym_09a/mni_icbm152_t1_tal_nlin_sym_09a.nii'

# Verify zip file
if not os.path.exists(ZIP_PATH):
    print(f"Error: Zip file {ZIP_PATH} not found. Please upload it to /content/")
    sys.exit(1)

# List zip contents
print("Zip file contents:")
with zipfile.ZipFile(ZIP_PATH, 'r') as z:
    zip_files = z.namelist()
    for fname in zip_files:
        print(f" - {fname}")
    data_files = [f for f in zip_files if f.startswith('Data/') and f.endswith(('.nii', '.nii.gz'))]
    print(f"Found {len(data_files)} .nii/.nii.gz files in zip under Data/")

# Unzip
os.makedirs(RAW_DIR, exist_ok=True)
with zipfile.ZipFile(ZIP_PATH, 'r') as z:
    z.extractall(RAW_DIR)
print(f"Unzipped to {RAW_DIR}")

# Verify unzipped files
print("Unzipped directory contents:")
for cls in ['Mild Dementia', 'Moderate Dementia', 'Non Demented', 'Very mild Dementia']:
    cls_dir = os.path.join(RAW_DIR, 'Data', cls)
    if os.path.exists(cls_dir):
        nii_files = glob(os.path.join(cls_dir, '*.nii*'))
        print(f" - {cls_dir}: {len(nii_files)} .nii/.nii.gz files")
        for f in nii_files:
            print(f"   - {f} (size: {os.path.getsize(f)} bytes)")
    else:
        print(f" - {cls_dir}: Directory not found")

# Fetch MNI template if not present
if not os.path.exists(MNI_TEMPLATE):
    icbm = datasets.fetch_icbm152_2009(data_dir='/content')
    MNI_TEMPLATE = icbm.t1
    print(f"Fetched MNI template to {MNI_TEMPLATE}")

# Preprocess
os.makedirs(PREPROC_DIR, exist_ok=True)
classes = ['Mild Dementia', 'Moderate Dementia', 'Non Demented', 'Very mild Dementia']
for cls in classes:
    src = os.path.join(RAW_DIR, 'Data', cls)
    dst = os.path.join(PREPROC_DIR, cls)
    os.makedirs(dst, exist_ok=True)
    files = sorted(glob(os.path.join(src, '*.nii*')))
    if args.max_files:
        files = files[:args.max_files]
    if not files:
        print(f"No .nii files found in {src}")
        continue
    print(f"Processing {len(files)} files in {src}")
    for fpath in files:
        try:
            print(f"Processing {fpath}")
            img = sitk.ReadImage(fpath)
            print(f" - Loaded image: {fpath}, size={img.GetSize()}")
            img = sitk.N4BiasFieldCorrectionImageFilter().Execute(img)
            mask = sitk.OtsuThreshold(img, 0, 1)
            img = sitk.Mask(img, mask)
            template_img = sitk.ReadImage(MNI_TEMPLATE)
            reg = sitk.ImageRegistrationMethod()
            reg.SetMetricAsMeanSquares()
            reg.SetOptimizerAsGradientDescent(1.0, 100)
            init_t = sitk.CenteredTransformInitializer(template_img, img, sitk.Euler3DTransform())
            reg.SetInitialTransform(init_t)
            trans = reg.Execute(template_img, img)
            img = sitk.Resample(img, template_img, trans, sitk.sitkLinear, 0.0, img.GetPixelID())
            arr = sitk.GetArrayFromImage(img).astype(np.float32)
            arr = (arr - arr.min()) / (arr.max() - arr.min() + 1e-6)
            out_path = os.path.join(dst, os.path.basename(fpath).replace('.nii', '.npy'))
            np.save(out_path, arr)
            print(f"Saved {out_path} (size: {os.path.getsize(out_path)} bytes)")
        except Exception as e:
            print(f"Error processing {fpath}: {str(e)}")

# Verify output
print("Preprocessing output:")
for cls in classes:
    dst = os.path.join(PREPROC_DIR, cls)
    npy_files = glob(os.path.join(dst, '*.npy'))
    print(f" - {dst}: {len(npy_files)} .npy files")
    for f in npy_files:
        print(f"   - {f} (size: {os.path.getsize(f)} bytes)")

# Load atlas
atlas_img = '/content/gray_matter_mask.nii.gz'
try:
    atlas_data = nib.load(atlas_img).get_fdata()
    print(f"Loaded gray matter mask from {atlas_img}")
except (FileNotFoundError, nib.filebasedimages.ImageFileError):
    from nilearn.datasets import fetch_atlas_harvard_oxford
    atlas_res = fetch_atlas_harvard_oxford('cort-maxprob-thr25-1mm')
    maps = atlas_res.maps
    if isinstance(maps, str):
        atlas_data = nib.load(maps).get_fdata() > 0
    else:
        atlas_data = maps.get_fdata() > 0
    print(f"Fetched Harvard-Oxford atlas mask from: {maps}")
atlas = atlas_data.astype(float).flatten()

# Save atlas
np.save('/content/atlas.npy', atlas)
print("Saved atlas to /content/atlas.npy")
# Out:
# Overwriting preprocess.py

# %% [markdown]
# #-Dataset -

# %%
# %%writefile dataset.py
import os
import numpy as np
import torch
import torchio as tio
import SimpleITK as sitk
from torch.utils.data import Dataset

class OASIS3DDataset(Dataset):
    LABELS = {
        'Mild Dementia': 0,
        'Moderate Dementia': 1,
        'Non Demented': 2,
        'Very mild Dementia': 3
    }

    def __init__(self, preproc_dir, atlas, patch_size, stride, N, augment=True, max_files=None):
        self.ps = patch_size
        self.stride = stride
        self.N = N
        self.samples = []
        self.preproc_dir = preproc_dir

        for cls, lab in self.LABELS.items():
            folder = os.path.join(preproc_dir, cls)
            if not os.path.isdir(folder):
                print(f"Warning: missing folder '{cls}' -> {folder}")
                continue
            npy_files = sorted([f for f in os.listdir(folder) if f.endswith('.npy')])
            nii_files = sorted([f for f in os.listdir(folder) if f.endswith(('.nii', '.nii.gz'))])
            if npy_files:
                use_npy = True
                files = npy_files
            else:
                use_npy = False
                files = nii_files
            if max_files:
                files = files[:max_files]
            if not files:
                print(f"Warning: no .npy or .nii in {folder}")
                continue
            print(f"Found {len(files)} files for class '{cls}' using {'npy' if use_npy else 'nii'}")
            for fname in files:
                self.samples.append((os.path.join(folder, fname), lab, use_npy))

        if not self.samples:
            raise ValueError("No samples found—did you run preprocessing?")

        self.atlas = atlas.astype(float) / (atlas.sum() + 1e-6)
        self.aug = tio.Compose([
            tio.RandomAffine(scales=(0.9, 1.1), degrees=10),
            tio.RandomNoise()
        ]) if augment else None

    def __len__(self):
        return len(self.samples)

    def sample_centers(self, vol_shape):
        D, H, W = vol_shape
        idxs = np.random.choice(D * H * W, self.N, p=self.atlas)
        coords = []
        for idx in idxs:
            z = idx // (H * W)
            rem = idx % (H * W)
            y = rem // W
            x = rem % W
            coords.append((z, y, x))
        return coords

    def __getitem__(self, idx):
        fpath, label, use_npy = self.samples[idx]
        vol = np.load(fpath) if use_npy else sitk.GetArrayFromImage(sitk.ReadImage(fpath))
        if self.aug:
            vol = self.aug(tio.ScalarImage(tensor=torch.tensor(vol)[None])['data']).numpy()[0]
        centers = self.sample_centers(vol.shape)
        patches = []
        for z, y, x in centers:
            patch = vol[z:z+self.ps, y:y+self.ps, x:x+self.ps]
            if patch.shape != (self.ps, self.ps, self.ps):
                patch = np.pad(patch, [(0, max(0, self.ps - patch.shape[i])) for i in range(3)], mode='constant')
            patches.append(patch)
        patches = torch.tensor(np.stack(patches), dtype=torch.float32).unsqueeze(1)
        return patches, torch.tensor(label, dtype=torch.long)
# Out:
# Overwriting dataset.py

# %% [markdown]
# #Model

# %%
# %%writefile model.py
import torch
import torch.nn as nn
import numpy as np
import os
from sklearn.cluster import KMeans
from torch.utils.data import DataLoader
from dataset import OASIS3DDataset

# Verify atlas exists
if not os.path.exists('/content/atlas.npy'):
    raise FileNotFoundError("Atlas file /content/atlas.npy not found. Run preprocess.py first.")

# Load atlas
atlas = np.load('/content/atlas.npy')

# Define dataset
train_dataset = OASIS3DDataset(
    preproc_dir='/content/oasis_preproc',
    atlas=atlas,
    patch_size=32,
    stride=32,
    N=64,
    augment=True,
    max_files=None
)

# Define kmeans_loader
kmeans_loader = DataLoader(
    train_dataset,
    batch_size=2,
    shuffle=True
)

class PatchEncoder3D(nn.Module):
    def __init__(self, emb_dim):
        super(PatchEncoder3D, self).__init__()
        self.net = nn.Sequential(
            nn.Conv3d(1, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool3d(2),
            nn.Conv3d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool3d(2),
            nn.Conv3d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool3d(2),
            nn.Conv3d(128, emb_dim, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.AdaptiveAvgPool3d(1)
        )

    def forward(self, x):
        out = self.net(x)
        return out.view(x.size(0), -1)

class AttentionMIL(nn.Module):
    def __init__(self, emb_dim):
        super(AttentionMIL, self).__init__()
        self.attn = nn.Sequential(
            nn.Linear(emb_dim, emb_dim // 2),
            nn.Tanh(),
            nn.Linear(emb_dim // 2, 1)
        )

    def forward(self, H):
        w = torch.softmax(self.attn(H), dim=1)
        bag = (w * H).sum(dim=1)
        return bag, w.squeeze(-1)

class PMICL3D(nn.Module):
    def __init__(self, emb_dim, num_classes, proto_tau, protos_per_class, init_kmeans=False, kmeans_loader=None):
        super(PMICL3D, self).__init__()
        self.encoder = PatchEncoder3D(emb_dim)
        self.pool = AttentionMIL(emb_dim)
        self.classifier = nn.Linear(emb_dim, num_classes)
        self.tau = proto_tau
        self.num_classes = num_classes
        self.K = protos_per_class
        self.prototypes = nn.Parameter(torch.randn(num_classes * protos_per_class, emb_dim))
        if init_kmeans and kmeans_loader is not None:
            self._init_prototypes(kmeans_loader)

    def _init_prototypes(self, loader):
        feats_list, labs_list = [], []
        with torch.no_grad():
            for bags, y in loader:
                bags = bags.to(self.encoder.net[0].weight.device)
                B, N, C, D, H, W = bags.shape
                bags_flat = bags.view(B * N, C, D, H, W)
                H_flat = self.encoder(bags_flat)
                feats_list.append(H_flat.cpu().numpy())
                y_repeated = y.repeat_interleave(N).cpu().numpy()
                labs_list.append(y_repeated)
        feats = np.concatenate(feats_list, axis=0)
        labs = np.concatenate(labs_list, axis=0)
        centers = []
        for c in range(self.num_classes):
            feats_c = feats[labs == c]
            if len(feats_c) >= self.K:
                km = KMeans(n_clusters=self.K).fit(feats_c)
                centers.append(km.cluster_centers_)
            else:
                reps = np.tile(feats_c, (int(np.ceil(self.K / len(feats_c))), 1))
                centers.append(reps[:self.K])
        all_centers = np.vstack(centers)
        self.prototypes.data.copy_(torch.tensor(all_centers, dtype=torch.float32).to(self.prototypes.device))

    def forward(self, X):
        B = X.size(0) // self.K
        H_flat = self.encoder(X)
        H = H_flat.view(B, self.K, -1)
        bag, attn = self.pool(H)
        logits = self.classifier(bag)
        return logits, H, attn

    def prototype_loss(self, H, y):
        B, K, D = H.shape
        Hf = H.view(B * K, D)
        sims = torch.matmul(Hf, self.prototypes.t()) / self.tau
        targets = []
        for b in range(B):
            cls = y[b].item()
            idx_start = cls * self.K
            idxs = list(range(idx_start, idx_start + self.K))
            sims_b = torch.matmul(H[b], self.prototypes[idxs].t()) / self.tau
            nearest = sims_b.argmax(dim=1)
            targets += [idxs[n.item()] for n in nearest]
        targets = torch.tensor(targets, device=sims.device)
        return nn.CrossEntropyLoss()(sims, targets)

# Instantiate model
model = PMICL3D(
    emb_dim=256,
    num_classes=4,
    proto_tau=0.5,
    protos_per_class=3,
    init_kmeans=True,
    kmeans_loader=kmeans_loader
).to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
# Out:
# Overwriting model.py

# %% [markdown]
# #Training Loop

# %%
# %%writefile train.py
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.metrics import accuracy_score
from torch.utils.data import DataLoader
from dataset import OASIS3DDataset
from model import PMICL3D

# Define hyperparameters (matching preprocess.py)
class Args:
    emb_dim = 256
    protos_per_class = 3
    lambda_proto = 0.5
    patch_size = 32
    stride = 32
    N = 64
    max_files = None
    epochs = 20
    batch_size = 2

args = Args()

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load atlas
if not os.path.exists('/content/atlas.npy'):
    raise FileNotFoundError("Atlas file /content/atlas.npy not found. Run preprocess.py first.")
atlas = np.load('/content/atlas.npy')

# Define dataset
train_dataset = OASIS3DDataset(
    preproc_dir='/content/oasis_preproc',
    atlas=atlas,
    patch_size=args.patch_size,
    stride=args.stride,
    N=args.N,
    augment=True,
    max_files=args.max_files
)

# Define train_loader
train_loader = DataLoader(
    train_dataset,
    batch_size=args.batch_size,
    shuffle=True
)

# Instantiate model
model = PMICL3D(
    emb_dim=args.emb_dim,
    num_classes=4,
    proto_tau=args.lambda_proto,
    protos_per_class=args.protos_per_class,
    init_kmeans=True,
    kmeans_loader=train_loader  # Reuse train_loader for KMeans initialization
).to(device)

# Training loop
optimizer = optim.Adam(model.parameters(), lr=1e-4)
for ep in range(1, args.epochs + 1):
    model.train()
    total_loss = 0
    all_preds, all_labels = [], []
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        logits, H, attn = model(X)
        ce = nn.CrossEntropyLoss()(logits, y)
        proto = model.prototype_loss(H, y)
        loss = ce + args.lambda_proto * proto
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        all_preds += logits.argmax(1).cpu().tolist()
        all_labels += y.cpu().tolist()
    avg_loss = total_loss / len(train_loader)
    acc = accuracy_score(all_labels, all_preds)
    print(f"Epoch {ep}: Loss={avg_loss:.3f}, Acc={acc:.3f}")
    # Save checkpoint
    torch.save(model.state_dict(), f'pmicl_epoch{ep}.pth')
# Out:
# Overwriting train.py

# %%
# !python preprocess.py
# Out:
# Streaming output truncated to the last 5000 lines.
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_115.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_116.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_117.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_118.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_119.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_120.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_121.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_122.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_123.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_124.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_125.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_126.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_127.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_128.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_129.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_130.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_131.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_132.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_133.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_134.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_135.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_136.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_137.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_138.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_139.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_140.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_141.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_142.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_143.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_144.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_145.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_146.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_147.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_148.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_149.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_150.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_151.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_152.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_153.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_154.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_155.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_156.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_157.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_158.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_159.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-1_160.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_100.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_101.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_102.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_103.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_104.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_105.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_106.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_107.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_108.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_109.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_110.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_111.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_112.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_113.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_114.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_115.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_116.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_117.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_118.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_119.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_120.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_121.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_122.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_123.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_124.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_125.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_126.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_127.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_128.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_129.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_130.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_131.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_132.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_133.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_134.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_135.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_136.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_137.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_138.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_139.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_140.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_141.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_142.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_143.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_144.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_145.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_146.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_147.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_148.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_149.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_150.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_151.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_152.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_153.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_154.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_155.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_156.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_157.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_158.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_159.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-2_160.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_100.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_101.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_102.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_103.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_104.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_105.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_106.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_107.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_108.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_109.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_110.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_111.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_112.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_113.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_114.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_115.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_116.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_117.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_118.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_119.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_120.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_121.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_122.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_123.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_124.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_125.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_126.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_127.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_128.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_129.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_130.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_131.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_132.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_133.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_134.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_135.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_136.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_137.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_138.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_139.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_140.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_141.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_142.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_143.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_144.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_145.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_146.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_147.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_148.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_149.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_150.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_151.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_152.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_153.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_154.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_155.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_156.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_157.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_158.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_159.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-3_160.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_100.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_101.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_102.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_103.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_104.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_105.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_106.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_107.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_108.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_109.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_110.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_111.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_112.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_113.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_114.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_115.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_116.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_117.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_118.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_119.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_120.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_121.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_122.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_123.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_124.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_125.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_126.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_127.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_128.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_129.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_130.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_131.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_132.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_133.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_134.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_135.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_136.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_137.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_138.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_139.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_140.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_141.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_142.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_143.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_144.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_145.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_146.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_147.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_148.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_149.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_150.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_151.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_152.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_153.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_154.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_155.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_156.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_157.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_158.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_159.jpg
#  - Data/Very mild Dementia/OAS1_0263_MR1_mpr-4_160.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_100.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_101.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_102.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_103.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_104.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_105.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_106.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_107.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_108.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_109.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_110.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_111.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_112.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_113.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_114.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_115.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_116.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_117.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_118.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_119.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_120.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_121.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_122.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_123.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_124.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_125.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_126.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_127.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_128.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_129.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_130.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_131.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_132.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_133.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_134.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_135.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_136.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_137.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_138.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_139.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_140.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_141.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_142.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_143.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_144.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_145.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_146.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_147.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_148.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_149.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_150.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_151.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_152.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_153.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_154.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_155.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_156.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_157.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_158.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_159.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-1_160.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_100.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_101.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_102.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_103.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_104.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_105.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_106.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_107.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_108.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_109.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_110.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_111.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_112.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_113.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_114.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_115.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_116.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_117.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_118.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_119.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_120.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_121.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_122.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_123.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_124.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_125.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_126.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_127.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_128.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_129.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_130.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_131.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_132.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_133.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_134.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_135.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_136.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_137.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_138.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_139.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_140.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_141.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_142.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_143.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_144.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_145.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_146.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_147.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_148.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_149.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_150.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_151.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_152.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_153.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_154.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_155.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_156.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_157.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_158.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_159.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-2_160.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_100.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_101.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_102.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_103.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_104.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_105.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_106.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_107.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_108.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_109.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_110.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_111.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_112.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_113.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_114.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_115.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_116.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_117.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_118.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_119.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_120.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_121.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_122.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_123.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_124.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_125.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_126.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_127.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_128.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_129.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_130.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_131.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_132.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_133.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_134.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_135.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_136.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_137.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_138.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_139.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_140.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_141.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_142.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_143.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_144.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_145.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_146.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_147.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_148.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_149.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_150.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_151.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_152.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_153.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_154.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_155.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_156.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_157.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_158.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_159.jpg
#  - Data/Very mild Dementia/OAS1_0267_MR1_mpr-3_160.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_100.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_101.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_102.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_103.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_104.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_105.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_106.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_107.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_108.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_109.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_110.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_111.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_112.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_113.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_114.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_115.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_116.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_117.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_118.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_119.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_120.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_121.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_122.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_123.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_124.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_125.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_126.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_127.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_128.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_129.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_130.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_131.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_132.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_133.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_134.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_135.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_136.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_137.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_138.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_139.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_140.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_141.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_142.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_143.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_144.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_145.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_146.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_147.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_148.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_149.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_150.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_151.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_152.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_153.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_154.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_155.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_156.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_157.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_158.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_159.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-1_160.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_100.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_101.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_102.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_103.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_104.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_105.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_106.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_107.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_108.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_109.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_110.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_111.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_112.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_113.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_114.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_115.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_116.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_117.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_118.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_119.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_120.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_121.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_122.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_123.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_124.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_125.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_126.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_127.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_128.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_129.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_130.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_131.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_132.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_133.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_134.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_135.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_136.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_137.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_138.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_139.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_140.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_141.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_142.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_143.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_144.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_145.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_146.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_147.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_148.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_149.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_150.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_151.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_152.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_153.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_154.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_155.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_156.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_157.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_158.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_159.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-2_160.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_100.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_101.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_102.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_103.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_104.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_105.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_106.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_107.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_108.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_109.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_110.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_111.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_112.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_113.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_114.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_115.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_116.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_117.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_118.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_119.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_120.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_121.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_122.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_123.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_124.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_125.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_126.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_127.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_128.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_129.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_130.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_131.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_132.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_133.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_134.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_135.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_136.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_137.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_138.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_139.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_140.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_141.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_142.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_143.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_144.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_145.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_146.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_147.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_148.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_149.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_150.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_151.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_152.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_153.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_154.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_155.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_156.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_157.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_158.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_159.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-3_160.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_100.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_101.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_102.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_103.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_104.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_105.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_106.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_107.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_108.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_109.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_110.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_111.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_112.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_113.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_114.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_115.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_116.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_117.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_118.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_119.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_120.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_121.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_122.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_123.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_124.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_125.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_126.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_127.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_128.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_129.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_130.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_131.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_132.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_133.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_134.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_135.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_136.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_137.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_138.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_139.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_140.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_141.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_142.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_143.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_144.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_145.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_146.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_147.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_148.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_149.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_150.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_151.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_152.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_153.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_154.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_155.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_156.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_157.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_158.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_159.jpg
#  - Data/Very mild Dementia/OAS1_0272_MR1_mpr-4_160.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_100.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_101.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_102.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_103.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_104.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_105.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_106.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_107.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_108.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_109.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_110.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_111.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_112.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_113.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_114.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_115.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_116.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_117.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_118.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_119.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_120.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_121.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_122.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_123.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_124.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_125.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_126.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_127.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_128.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_129.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_130.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_131.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_132.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_133.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_134.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_135.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_136.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_137.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_138.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_139.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_140.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_141.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_142.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_143.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_144.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_145.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_146.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_147.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_148.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_149.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_150.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_151.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_152.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_153.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_154.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_155.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_156.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_157.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_158.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_159.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-1_160.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_100.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_101.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_102.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_103.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_104.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_105.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_106.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_107.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_108.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_109.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_110.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_111.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_112.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_113.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_114.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_115.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_116.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_117.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_118.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_119.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_120.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_121.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_122.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_123.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_124.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_125.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_126.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_127.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_128.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_129.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_130.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_131.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_132.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_133.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_134.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_135.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_136.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_137.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_138.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_139.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_140.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_141.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_142.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_143.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_144.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_145.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_146.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_147.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_148.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_149.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_150.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_151.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_152.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_153.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_154.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_155.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_156.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_157.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_158.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_159.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-2_160.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_100.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_101.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_102.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_103.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_104.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_105.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_106.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_107.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_108.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_109.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_110.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_111.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_112.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_113.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_114.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_115.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_116.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_117.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_118.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_119.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_120.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_121.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_122.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_123.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_124.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_125.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_126.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_127.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_128.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_129.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_130.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_131.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_132.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_133.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_134.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_135.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_136.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_137.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_138.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_139.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_140.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_141.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_142.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_143.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_144.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_145.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_146.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_147.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_148.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_149.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_150.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_151.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_152.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_153.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_154.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_155.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_156.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_157.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_158.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_159.jpg
#  - Data/Very mild Dementia/OAS1_0273_MR1_mpr-3_160.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_100.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_101.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_102.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_103.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_104.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_105.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_106.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_107.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_108.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_109.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_110.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_111.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_112.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_113.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_114.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_115.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_116.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_117.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_118.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_119.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_120.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_121.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_122.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_123.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_124.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_125.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_126.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_127.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_128.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_129.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_130.jpg
#  - Data/Very mild Dementia/OAS1_0286_MR1_mpr-1_131.jpg
# ...
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_100.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_101.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_102.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_103.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_104.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_105.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_106.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_107.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_108.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_109.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_110.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_111.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_112.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_113.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_114.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_115.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_116.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_117.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_118.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_119.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_120.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_121.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_122.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_123.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_124.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_125.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_126.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_127.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_128.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_129.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_130.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_131.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_132.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_133.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_134.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_135.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_136.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_137.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_138.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_139.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_140.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_141.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_142.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_143.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_144.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_145.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_146.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_147.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_148.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_149.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_150.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_151.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_152.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_153.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_154.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_155.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_156.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_157.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_158.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_159.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-1_160.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_100.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_101.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_102.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_103.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_104.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_105.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_106.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_107.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_108.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_109.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_110.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_111.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_112.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_113.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_114.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_115.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_116.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_117.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_118.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_119.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_120.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_121.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_122.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_123.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_124.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_125.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_126.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_127.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_128.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_129.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_130.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_131.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_132.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_133.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_134.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_135.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_136.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_137.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_138.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_139.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_140.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_141.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_142.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_143.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_144.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_145.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_146.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_147.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_148.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_149.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_150.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_151.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_152.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_153.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_154.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_155.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_156.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_157.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_158.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_159.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-2_160.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_100.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_101.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_102.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_103.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_104.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_105.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_106.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_107.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_108.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_109.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_110.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_111.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_112.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_113.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_114.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_115.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_116.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_117.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_118.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_119.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_120.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_121.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_122.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_123.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_124.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_125.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_126.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_127.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_128.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_129.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_130.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_131.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_132.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_133.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_134.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_135.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_136.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_137.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_138.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_139.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_140.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_141.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_142.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_143.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_144.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_145.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_146.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_147.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_148.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_149.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_150.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_151.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_152.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_153.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_154.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_155.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_156.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_157.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_158.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_159.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-3_160.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_100.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_101.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_102.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_103.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_104.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_105.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_106.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_107.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_108.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_109.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_110.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_111.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_112.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_113.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_114.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_115.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_116.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_117.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_118.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_119.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_120.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_121.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_122.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_123.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_124.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_125.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_126.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_127.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_128.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_129.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_130.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_131.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_132.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_133.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_134.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_135.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_136.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_137.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_138.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_139.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_140.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_141.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_142.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_143.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_144.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_145.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_146.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_147.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_148.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_149.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_150.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_151.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_152.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_153.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_154.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_155.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_156.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_157.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_158.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_159.jpg
#  - Data/Very mild Dementia/OAS1_0380_MR1_mpr-4_160.jpg
# Found 0 .nii/.nii.gz files in zip under Data/
# Unzipped to /content/oasis_raw
# Unzipped directory contents:
#  - /content/oasis_raw/Data/Mild Dementia: 0 .nii/.nii.gz files
#  - /content/oasis_raw/Data/Moderate Dementia: 0 .nii/.nii.gz files
#  - /content/oasis_raw/Data/Non Demented: 0 .nii/.nii.gz files
#  - /content/oasis_raw/Data/Very mild Dementia: 0 .nii/.nii.gz files
# [get_dataset_dir] Dataset found in /content/icbm152_2009
# Fetched MNI template to /content/icbm152_2009/mni_icbm152_nlin_sym_09a/mni_icbm152_t1_tal_nlin_sym_09a.nii.gz
# No .nii files found in /content/oasis_raw/Data/Mild Dementia
# No .nii files found in /content/oasis_raw/Data/Moderate Dementia
# No .nii files found in /content/oasis_raw/Data/Non Demented
# No .nii files found in /content/oasis_raw/Data/Very mild Dementia
# Preprocessing output:
#  - /content/oasis_preproc/Mild Dementia: 0 .npy files
#  - /content/oasis_preproc/Moderate Dementia: 0 .npy files
#  - /content/oasis_preproc/Non Demented: 0 .npy files
#  - /content/oasis_preproc/Very mild Dementia: 0 .npy files
# [get_dataset_dir] Dataset found in /root/nilearn_data/fsl
# Fetched Harvard-Oxford atlas mask from:
# <class 'nibabel.nifti1.Nifti1Image'>
# data shape (182, 218, 182)
# affine:
# [[   1.    0.    0.  -91.]
#  [   0.    1.    0. -126.]
#  [   0.    0.    1.  -72.]
#  [   0.    0.    0.    1.]]
# metadata:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 0
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  3 182 218 182   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : uint8
# bitpix          : 8
# slice_start     : 0
# pixdim          : [1. 1. 1. 1. 1. 1. 1. 1.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 48.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'FSL3.3')
# aux_file        : np.bytes_(b'MGH-Cortical')
# qform_code      : unknown
# sform_code      : aligned
# quatern_b       : 0.0
# quatern_c       : 0.0
# quatern_d       : 0.0
# qoffset_x       : -91.0
# qoffset_y       : -126.0
# qoffset_z       : -72.0
# srow_x          : [  1.   0.   0. -91.]
# srow_y          : [   0.    1.    0. -126.]
# srow_z          : [  0.   0.   1. -72.]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
#
# Saved atlas to /content/atlas.npy

# %% [markdown]
# #Evaluation

# %%
model.eval(); preds,probs,labs=[],[],[]
with torch.no_grad():
    for X,y in val_loader:
        X,y=X.to(device),y.to(device)
        logits,H,attn=model(X)
        p=torch.softmax(logits,1).cpu().numpy()
        preds+=logits.argmax(1).cpu().tolist(); probs+=p.tolist(); labs+=y.cpu().tolist()
print("Val Acc",accuracy_score(labs,preds))
print("ROC AUC",roc_auc_score(np.eye(model.num_classes)[labs],probs,multi_class='ovr'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-11c0e29e7156> in <cell line: 0>()
# ----> 1 model.eval(); preds,probs,labs=[],[],[]
#       2 with torch.no_grad():
#       3     for X,y in val_loader:
#       4         X,y=X.to(device),y.to(device)
#       5         logits,H,attn=model(X)
#
# NameError: name 'model' is not defined

# %% [markdown]
# #Interpretability

# %%
import matplotlib.pyplot as plt

def visualize_attention_3d(volume,attn,centers):
    heatmap=np.zeros_like(volume)
    for (z,y,x),a in zip(centers,attn): heatmap[z:z+args.patch_size,y:y+args.patch_size,x:x+args.patch_size]+=a
    # visualize central slice
    plt.imshow(heatmap[heatmap.shape[0]//2], cmap='hot'); plt.title('3D Attention Heatmap'); plt.show()
